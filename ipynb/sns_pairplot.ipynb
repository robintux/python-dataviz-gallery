# %% [markdown]
# ## Pair Plot in Seaborn

# %%
# %load_ext watermark
# %watermark -a 'Hideki Tanaka' -u -d -v -p matplotlib,numpy,pandas,seaborn
# Out:
# Hideki Tanaka
# last updated: 2016-02-23
#
# CPython 3.5.1
# IPython 4.1.1
#
# matplotlib 1.5.1
# numpy 1.10.4
# pandas 0.17.1
# seaborn 0.7.0

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
np.random.seed(0)

# %%
n = 500
d = {'x': np.random.randn(n),
     'y': np.random.randn(n),
     'z': np.random.randn(n)}

# %%
df = pd.DataFrame(d)

# %%
fig = sns.pairplot(df)

# %%
fig.savefig('../images/sns_pairplot.png', dpi=80)
